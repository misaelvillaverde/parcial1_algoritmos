# %%
from constants import URL, LOCAL
import requests

# %%
def gt(route):
  return requests.get(f"http://localhost:5000/{route}").json()

# %%
gt("provinces")
# Out:
# [{'_id': '617630d7f79ed7fbc3bd80bd',
#   'name': 'Panamá',
#   'image': './provincia_comarcas/1.gif',
#   'description': 'Panamá es una de las diez provincias de Panamá. La misma tiene una superficie de 9 mil 166 km²,\u200b la cual limita al norte con la provincia de Colón y la Comarca Guna Yala, al sur con el Océano Pacífico; al este con la provincia de Darién y la comarca Wargandí y al oeste con la provincia de Panamá Oeste.',
#   'indigenousRegion': False,
#   'turisticPlaces': [{'benefits': [],
#     '_id': '61763dd73aa0973cdcb9ae5c',
#     'name': 'Panamá Viejo',
#     'image': './atraccion/1.gif',
#     'description': 'Recibe el nombre de panamá la vieja al sitio donde estuvo ubicada la ciudad de Panamá desde el 1519, la ciudad fue trasladada a una nueva ubicación, a unos 10 Km al suroeste, al quedar destruido por el ataque del pirata Henry Morgan, y actualmente se encuentra ubicado en la ciudad de Panamá, sobre la vía cincuentenario.',
#     'cost': 40,
# ...

# %% [markdown]
# # print image of province
# <img src="../assets/provincia_comarcas/1.gif" align="center">
